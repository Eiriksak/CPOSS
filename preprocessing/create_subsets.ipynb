# %%
import pandas as pd

# %%
traf_track = pd.read_csv("../data/traffic_tracker.csv")

# %%
traf_track.shape
# Out:
# (19590699, 5)

# %%
traf_track.head()
# Out:
#                      TIME  SEGMENTID  BUS COUNT                  \
# 0  01/16/2013 11:50:32 PM        116                        2.0
# 1  02/24/2013 11:50:32 PM         54                        2.0
# 2  02/17/2013 11:50:32 PM        597                        0.0
# 3  02/23/2013 11:50:32 PM        363                        1.0
# 4  12/01/2014 11:50:32 PM        203                        0.0
#
#    MESSAGE COUNT  SPEED
# 0            7.0     18
# 1           11.0     23
# 2            0.0     -1
# 3            4.0     25
# 4            0.0     -1

# %%
crimes = pd.read_csv("../data/crimes.csv")
# Out:
# /home/ubuntu/anaconda3/envs/dat500/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
a = crimes["Longitude"].value_counts().index.to_list()

# %%
for l in a:
    if l > -87:
        print(l)

# %%
crimes.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
crimes["District"].value_counts()
# Out:
# 8.0     478290
# 11.0    453889
# 7.0     415241
# 6.0     409006
# 25.0    405441
# 4.0     399666
# 3.0     358166
# 9.0     348914
# 12.0    346360
# 2.0     334164
# 19.0    315158
# 18.0    314955
# 5.0     312983
# 15.0    306785
# 10.0    303698
# 1.0     280846
# 14.0    277561
# 16.0    233434
# 22.0    231153
# 24.0    210843
# 17.0    204057
# 20.0    122953
# 31.0       201
# 21.0         4
# Name: District, dtype: int64

# %%
district_11 = crimes[crimes["District"]==11.0]

# %%
district_11.to_csv("../data/district11.csv")

# %%
pd.read_csv("../data/district11.csv")
# Out:
#         Unnamed: 0        ID Case Number                    Date  \
# 0               24  11039126    JA371798  01/01/2007 12:01:00 AM
# 1               38  11042914    JA374555  01/01/2008 12:01:00 AM
# 2               44  11227513    JB137941  09/01/2017 09:00:00 AM
# 3               45  11223717    JB141803  02/04/2018 03:25:00 PM
# 4               59  11242963    JB168261  11/01/2014 09:00:00 AM
# ...            ...       ...         ...                     ...
# 453884     7063785   9999969    HY189942  03/18/2015 08:30:00 PM
# 453885     7063793   9999977    HY189948  03/18/2015 08:20:00 PM
# 453886     7063799   9999986    HY189728  03/18/2015 05:49:00 PM
# 453887     7063803   9999991    HY189924  03/18/2015 08:32:00 PM
# 453888     7063806   9999997    HY189887  03/18/2015 07:55:00 PM
#
#                           Block  IUCR         Primary Type  \
# 0             009XX N DRAKE AVE  0266  CRIM SEXUAL ASSAULT
# 1            011XX S WHIPPLE ST  0281  CRIM SEXUAL ASSAULT
# ...
